# %%
def findSum(numbers, queries):
    # Write your code here
    r=0
    for i in range(queries[0],queries[1]+1):
#         print(i)
        r=r+numbers[i-1]
    return r+queries[-1]

if __name__ == '__main__':
   

    numbers_count = int(input().strip())

    numbers = []

    for _ in range(numbers_count):
        numbers_item = int(input().strip())
        numbers.append(numbers_item)
    

    queries_rows = int(input().strip())
    queries_columns = int(input().strip())

    queries = []

    for _ in range(queries_rows):
        queries.append(map(int, input().rstrip().split()))

    result = findSum(numbers, queries)

    print(result)
    
"""  
3
5
10
10
1
3
1 2 5"""
# Out:
# 3
# 5
# 10
# 10
# 1
# 3
# 1 2 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8780/3570485323.py in <module>
#      27         queries.append(map(int, input().rstrip().split()))
#      28
# ---> 29     result = findSum(numbers, queries)
#      30
#      31     print(result)
#
# ~\AppData\Local\Temp/ipykernel_8780/3570485323.py in findSum(numbers, queries)
#       2     # Write your code here
#       3     r=0
# ----> 4     for i in range(queries[0],queries[1]+1):
#       5 #         print(i)
#       6         r=r+numbers[i-1]
#
# IndexError: list index out of range

# %%
numbers=[]
for _ in range(4):
    numbers_item = int(input().strip())
    numbers.append(numbers_item)
    
print(numbers)
# Out:
# 45
# 40
# 50
# 20
# [45, 40, 50, 20]

# %%
q=[1,3,10]
q[0]
# Out:
# 1

# %%
4
20
30
0
10
3
1
1
1
3
# Out:
# 62

# %%
def findSum(numbers, queries):
    r=0
    for i in range(queries[0],queries[1]+1):
#         print(i)
        if numbers[i-1]!=0:
            r=r+numbers[i-1]
#             print(r)
            #r+queries[-1]
            
        else:
            return r+numbers[i-1]+queries[-1]
        
    return r   
            
numbers=[5,50,10]
queries=[1, 2 ,5]
findSum(numbers, queries)
# Out:
# 55

# %%
# Out:
# 1

# %%
queries[3-1]
# Out:
# 10
